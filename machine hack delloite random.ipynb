# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
train=pd.read_csv("C:/Users/anos/3D Objects/Participants_Data_PLD/train.csv")
test=pd.read_csv("C:/Users/anos/3D Objects/Participants_Data_PLD/test.csv")

# %%
train.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  65087372        10000          32236             12329.36286    59
# 1   1450153         3609          11940             12191.99692    59
# 2   1969101        28276           9311             21603.22455    59
# 3   6651430        11170           6954             17877.15585    59
# 4  14354669        16890          13226             13539.92667    59
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2522922      11.135007     B        C4            MORTGAGE  ...
# 1     BAT1586599      12.237563     C        D3                RENT  ...
# 2     BAT2136391      12.545884     F        D4            MORTGAGE  ...
# 3     BAT2428731      16.731201     C        C3            MORTGAGE  ...
# 4     BAT5341619      15.008300     C        D4            MORTGAGE  ...
#
#     Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
test.head()
# Out:
#          ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0  56492997        17120          10365            16025.082690    59
# 1  22540813         7133          11650            12615.795600    59
# 2   9862181        25291          25825            11621.280830    59
# 3  10097822        30781           9664            15375.823510    59
# 4  47771809         8878           9419             7176.647582    58
#
#   Batch Enrolled  Interest Rate Grade Sub Grade Employment Duration  ...  \
# 0     BAT2575549      12.163926     A        D1                RENT  ...
# 1     BAT2833642       6.564296     B        E3            MORTGAGE  ...
# 2     BAT1761981      14.729900     A        C3            MORTGAGE  ...
# 3     BAT5341619      10.523767     A        A2                RENT  ...
# 4     BAT4694572       9.997013     C        B3                 OWN  ...
#
#    Recoveries Collection Recovery Fee Collection 12 months Medical  \
# ...

# %%
train.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  6.746300e+04  67463.000000   67463.000000            67463.000000
# mean   2.562761e+07  16848.902776   15770.599114            14621.799323
# std    2.109155e+07   8367.865726    8150.992662             6785.345170
# min    1.297933e+06   1014.000000    1014.000000             1114.590204
# 25%    6.570288e+06  10012.000000    9266.500000             9831.684984
# 50%    1.791565e+07  16073.000000   13042.000000            12793.682170
# 75%    4.271521e+07  22106.000000   21793.000000            17807.594120
# max    7.224578e+07  35000.000000   34999.000000            34999.746430
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  67463.000000   67463.000000    67463.000000     67463.000000
# mean      58.173814      11.846258    80541.502522        23.299241
# std        3.327441       3.718629    45029.120366         8.451824
# ...

# %%
test.describe()
# Out:
#                  ID   Loan Amount  Funded Amount  Funded Amount Investor  \
# count  2.891300e+04  28913.000000   28913.000000            28913.000000
# mean   2.944966e+07  16404.027462   15619.911113            14741.536698
# std    2.206842e+07   8358.898287    8229.977503             7230.397758
# min    1.297893e+06   1000.000000    1000.000000             1000.000000
# 25%    8.272049e+06   9776.000000    9175.000000             9695.445501
# 50%    2.596622e+07  15600.000000   13200.000000            12930.601270
# 75%    4.855801e+07  21651.000000   21552.000000            19226.397540
# max    7.226845e+07  35000.000000   35000.000000            35000.000000
#
#                Term  Interest Rate  Home Ownership  Debit to Income  \
# count  28913.000000   28913.000000    28913.000000     28913.000000
# mean      54.543078      12.187577    79983.752348        22.159266
# std        8.991800       3.911259    45231.316383         8.657629
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67463 entries, 0 to 67462
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            67463 non-null  int64
#  1   Loan Amount                   67463 non-null  int64
#  2   Funded Amount                 67463 non-null  int64
#  3   Funded Amount Investor        67463 non-null  float64
#  4   Term                          67463 non-null  int64
#  5   Batch Enrolled                67463 non-null  object
#  6   Interest Rate                 67463 non-null  float64
#  7   Grade                         67463 non-null  object
#  8   Sub Grade                     67463 non-null  object
#  9   Employment Duration           67463 non-null  object
#  10  Home Ownership                67463 non-null  float64
#  11  Verification Status           67463 non-null  object
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28913 entries, 0 to 28912
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            28913 non-null  int64
#  1   Loan Amount                   28913 non-null  int64
#  2   Funded Amount                 28913 non-null  int64
#  3   Funded Amount Investor        28913 non-null  float64
#  4   Term                          28913 non-null  int64
#  5   Batch Enrolled                28913 non-null  object
#  6   Interest Rate                 28913 non-null  float64
#  7   Grade                         28913 non-null  object
#  8   Sub Grade                     28913 non-null  object
#  9   Employment Duration           28913 non-null  object
#  10  Home Ownership                28913 non-null  float64
#  11  Verification Status           28913 non-null  object
# ...

# %%
sns.countplot(x=train['Employment Duration'])
# Out:
# <AxesSubplot:xlabel='Employment Duration', ylabel='count'>

# %%
sns.countplot(x=train['Term'])
# Out:
# <AxesSubplot:xlabel='Term', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=train['Batch Enrolled'])
plt.xticks(rotation=90)
plt.show()

# %%
train.hist(figsize=(20,20),bins=50)

plt.show()

# %%
sns.countplot(x=train['Term'])
# Out:
# <AxesSubplot:xlabel='Term', ylabel='count'>

# %%
plt.figure(figsize=(20,10))

sns.countplot(x=train['Sub Grade'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=train['Delinquency - two years'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=train['Public Record'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=train['Collection 12 months Medical'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=train['Loan Status'])
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x=test['Employment Duration'])
# Out:
# <AxesSubplot:xlabel='Employment Duration', ylabel='count'>

# %%
plt.figure(figsize=(20,10))

sns.countplot(x=test['Batch Enrolled'])
plt.xticks(rotation=90)
plt.show()

# %%
test.hist(figsize=(20,20),bins=50)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=test['Delinquency - two years'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=test['Public Record'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=test['Collection 12 months Medical'])
plt.xticks(rotation=90)
plt.show()

# %%
train.columns
# Out:
# Index(['ID', 'Loan Amount', 'Funded Amount', 'Funded Amount Investor', 'Term',
#        'Batch Enrolled', 'Interest Rate', 'Grade', 'Sub Grade',
#        'Employment Duration', 'Home Ownership', 'Verification Status',
#        'Payment Plan', 'Loan Title', 'Debit to Income',
#        'Delinquency - two years', 'Inquires - six months', 'Open Account',
#        'Public Record', 'Revolving Balance', 'Revolving Utilities',
#        'Total Accounts', 'Initial List Status', 'Total Received Interest',
#        'Total Received Late Fee', 'Recoveries', 'Collection Recovery Fee',
#        'Collection 12 months Medical', 'Application Type', 'Last week Pay',
#        'Accounts Delinquent', 'Total Collection Amount',
#        'Total Current Balance', 'Total Revolving Credit Limit', 'Loan Status'],
#       dtype='object')

# %%
train['Payment Plan'].unique(),train['Initial List Status'].unique(),train['Application Type'].unique()
# Out:
# (array(['n'], dtype=object),
#  array(['w', 'f'], dtype=object),
#  array(['INDIVIDUAL', 'JOINT'], dtype=object))

# %%
from sklearn import preprocessing
label_encoder =preprocessing.LabelEncoder()

# %%
train['Batch Enrolled']=label_encoder.fit_transform(train['Batch Enrolled'])
train['Grade']=label_encoder.fit_transform(train['Grade'])
train['Sub Grade']=label_encoder.fit_transform(train['Sub Grade'])
train['Employment Duration']=label_encoder.fit_transform(train['Employment Duration'])
train['Verification Status']=label_encoder.fit_transform(train['Verification Status'])
train['Loan Title']=label_encoder.fit_transform(train['Loan Title'])
train['Initial List Status']=label_encoder.fit_transform(train['Initial List Status'])
train['Application Type']=label_encoder.fit_transform(train['Application Type'])
train['Payment Plan']=label_encoder.fit_transform(train['Payment Plan'])

# %%
print(train)
train.info()
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      65087372        10000          32236             12329.36286    59
# 1       1450153         3609          11940             12191.99692    59
# 2       1969101        28276           9311             21603.22455    59
# 3       6651430        11170           6954             17877.15585    59
# 4      14354669        16890          13226             13539.92667    59
# ...         ...          ...            ...                     ...   ...
# 67458  16164945        13601           6848             13175.28583    59
# 67459  35182714         8323          11046             15637.46301    59
# 67460  16435904        15897          32921             12329.45775    59
# 67461   5300325        16567           4975             21353.68465    59
# 67462  65443173        15353          29875             14207.44860    59
#
#        Batch Enrolled  Interest Rate  Grade  Sub Grade  Employment Duration  \
# ...

# %%
test['Batch Enrolled']=label_encoder.fit_transform(test['Batch Enrolled'])
test['Grade']=label_encoder.fit_transform(test['Grade'])
test['Sub Grade']=label_encoder.fit_transform(test['Sub Grade'])
test['Employment Duration']=label_encoder.fit_transform(test['Employment Duration'])
test['Verification Status']=label_encoder.fit_transform(test['Verification Status'])
test['Loan Title']=label_encoder.fit_transform(test['Loan Title'])
test['Initial List Status']=label_encoder.fit_transform(test['Initial List Status'])
test['Application Type']=label_encoder.fit_transform(test['Application Type'])
test['Payment Plan']=label_encoder.fit_transform(test['Payment Plan'])

# %%
print(test)
test.info()
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 28908  11537800        35000          35000            35000.000000    60
# 28909  11538258        25000          25000            25000.000000    60
# 28910  13147685        30000          30000            29950.000000    60
# 28911  13917689        25000          25000            24950.000000    60
# 28912  10763026        24925          24925            24925.000000    60
#
#        Batch Enrolled  Interest Rate  Grade  Sub Grade  Employment Duration  \
# ...

# %%
from sklearn.metrics import mean_squared_error

# %%
test=test.drop(['Loan Status'],axis=1)

# %%
x=train.drop(['Loan Status'],axis=1)
y=train.pop('Loan Status')

# %%
y.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
test
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 0      56492997        17120          10365            16025.082690    59
# 1      22540813         7133          11650            12615.795600    59
# 2       9862181        25291          25825            11621.280830    59
# 3      10097822        30781           9664            15375.823510    59
# 4      47771809         8878           9419             7176.647582    58
# ...         ...          ...            ...                     ...   ...
# 28908  11537800        35000          35000            35000.000000    60
# 28909  11538258        25000          25000            25000.000000    60
# 28910  13147685        30000          30000            29950.000000    60
# 28911  13917689        25000          25000            24950.000000    60
# 28912  10763026        24925          24925            24925.000000    60
#
#        Batch Enrolled  Interest Rate  Grade  Sub Grade  Employment Duration  \
# ...

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
x_test
# Out:
#              ID  Loan Amount  Funded Amount  Funded Amount Investor  Term  \
# 24276  21984030        17916          11014            10167.667320    58
# 17131  32096001        11323          12248            22941.499190    59
# 21743   6334698        14020          13716            15061.032210    59
# 25213   2645024        17444           7713            22283.056090    59
# 38778  40510157        24897          15550            13590.521370    58
# ...         ...          ...            ...                     ...   ...
# 8064   38991876         4453          16657            14990.559180    59
# 31159   4397494        21357           7781             9913.668643    59
# 59722  43082649        23552           9141             9167.160181    59
# 1159   33385176        28790           9666            11393.672390    58
# 33347  49158112        26512           9236            15070.202000    58
#
#        Batch Enrolled  Interest Rate  Grade  Sub Grade  Employment Duration  \
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
print(y_pred)
accuracy_train = accuracy_score(y_test,y_pred)
print(accuracy_train)
# Out:
# C:\Users\anos\anaconda3\envs\ten_env\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:08:33] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0 0 0 ... 0 0 0]
# 0.9089520729461438

# %%
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier()  
model1.fit(x_train,y_train)
y_pred1=model1.predict(x_test)
print(y_pred1)
accuracy_train1 = accuracy_score(y_test,y_pred1)
print(accuracy_train1)
# Out:
# [0 0 0 ... 0 0 0]
# 0.9045052328976328

# %%
from sklearn.naive_bayes import GaussianNB
model2 = GaussianNB()
model2.fit(x_train,y_train)
y_pred2=model2.predict(x_test)
print(y_pred2)
accuracy_train2 = accuracy_score(y_test,y_pred2)
print(accuracy_train2)
# Out:
# [0 0 0 ... 0 0 0]
# 0.9070206171674976

# %%
from sklearn.tree import DecisionTreeClassifier
model3 = DecisionTreeClassifier()
model3.fit(x_train,y_train)
y_pred3=model3.predict(x_test)
print(y_pred3)
accuracy_train3 = accuracy_score(y_test,y_pred3)
print(accuracy_train3)
# Out:
# [0 0 0 ... 0 0 0]
# 0.8159726901136415

# %%
from sklearn.cluster import KMeans
model4 = KMeans()  
model4.fit(x_train,y_train)
y_pred4=model4.predict(x_test)
print(y_pred)
accuracy_train4 = accuracy_score(y_test,y_pred4)
print(accuracy_train4)
# Out:
# [0 0 0 ... 0 0 0]
# 0.2329874679962269

# %%
from sklearn.ensemble import RandomForestClassifier
model5 = RandomForestClassifier()
model5.fit(x_train,y_train)
y_pred5=model5.predict(x_test)
print(y_pred5)
accuracy_train5 = accuracy_score(y_test,y_pred5)
print(accuracy_train5)
# Out:
# [0 0 0 ... 0 0 0]
# 0.90958091901361

# %%
y1_pred=model5.predict(test)

# %%
sub=pd.read_csv('C:/Users/anos/3D Objects/Participants_Data_PLD/submission.csv')

# %%
sub['Loan Status']=pd.DataFrame(y1_pred)

# %%
sub.to_csv('C:/Users/anos/3D Objects/Participants_Data_PLD/submissionrandom.csv')
